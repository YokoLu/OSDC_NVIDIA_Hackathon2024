# %% [markdown]
# <a href="https://colab.research.google.com/github/SoulskyX/OSDC_NVIDIA_Hackathon2024/blob/main/osdc2024_nvidia_hackathon_matrix.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()
# Out:
# ...
# Kaggle credentials set.
# Kaggle credentials successfully validated.

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
odsc_2024_nvidia_hackathon_path = kagglehub.competition_download('odsc-2024-nvidia-hackathon')
print('Data source import complete.')
# this will be the final path
# "/root/.cache/kagglehub/competitions/odsc-2024-nvidia-hackathon"
# Out:
# ...
# 100%|██████████| 3.72G/3.72G [00:24<00:00, 163MB/s]
# Extracting files...
# Data source import complete.

# %%
! ls -al /root/.cache/kagglehub/competitions/odsc-2024-nvidia-hackathon
# Out:
# total 9096620
# drwxr-xr-x 2 root root       4096 Oct 30 23:00 .
# drwxr-xr-x 3 root root       4096 Oct 30 23:02 ..
# -rw-r--r-- 1 root root   26000005 Oct 30 23:00 sample-submission.csv
# -rw-r--r-- 1 root root  767139019 Oct 30 23:00 test.csv
# -rw-r--r-- 1 root root 8521780137 Oct 30 23:02 train.csv

# %%
import pandas as pd

# %%
df = pd.read_csv('/root/.cache/kagglehub/competitions/odsc-2024-nvidia-hackathon/train.csv',nrows=10000)

# %%
df.head()
# Out:
#    id          y          trickortreat        kingofhalloween   mumming  \
# 0   0  41703.824   century_totalrecall          wardrobe_noir  0.889825
# 1   1  42447.375  payday_consternation  groundhogday_language -0.583791
# 2   2  41882.582       jackpot_tragedy      fogmachine_heroes       NaN
# 3   3  42817.387      cape_experiences      multiday_carnival  0.416448
# 4   4  41827.844         shadow_issues    afterlife_cinematic  0.452739
#
#        noon  costumes  celebrate  confectionary  predestinated  ...  interday  \
# 0  4.672365  4.672365      13251       1.962392          33544  ...     46045
# 1  1.600765  1.600765      25515       0.573204          52520  ...     31884
# 2  6.129229  6.129229      37445       1.170098          40681  ...     43554
# 3  9.952353  9.952353      24654       0.421169          27995  ...     58797
# 4  2.257573  2.257573      28299      -0.285303          20220  ...     25380
#
# ...

# %%
df.describe()
# Out:
#                 id             y      mumming         noon     costumes  \
# count  10000.00000  10000.000000  9033.000000  9634.000000  9159.000000
# mean    4999.50000  42353.836059     0.011994     4.968387     4.973162
# std     2886.89568    677.458955     0.983114     2.888121     2.887949
# min        0.00000  29081.762000    -3.879818     0.001450     0.001450
# 25%     2499.75000  41902.501750    -0.638332     2.435929     2.449865
# 50%     4999.50000  42351.509500     0.014719     4.973270     4.977752
# 75%     7499.25000  42804.821250     0.678575     7.511288     7.508495
# max     9999.00000  44724.406000     3.884756     9.997619     9.997619
#
#           celebrate  confectionary  predestinated   leprechaun     headless  \
# count  10000.000000    9901.000000   10000.000000  9931.000000  9573.000000
# mean   17640.495400      -0.008105   26175.652700     0.499282     0.503732
# std    12265.916919       1.000555   16324.302619     0.287182     0.287643
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Columns: 108 entries, id to hallo
# dtypes: float64(52), int64(54), object(2)
# memory usage: 8.2+ MB

# %%
# load
# Step 1: Mount Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# Step 2: Access your file
import pandas as pd

# Replace 'your_file.csv' with the path to your file in Drive
file_path = '/content/drive/MyDrive/NVIDIA Hackathon 2024/YLsample2.snappy.parquet'
df = pd.read_parquet(file_path)

# Display the DataFrame
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-ffaa4e8fe908> in <cell line: 11>()
#       9 # Replace 'your_file.csv' with the path to your file in Drive
#      10 file_path = '/content/drive/MyDrive/NVIDIA Hackathon 2024/YLsample2.snappy.parquet'
# ---> 11 df = pd.read_parquet(file_path)
#      12
#      13 # Display the DataFrame
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read_parquet(path, engine, columns, storage_options, use_nullable_dtypes, dtype_backend, filesystem, filters, **kwargs)
#     665     check_dtype_backend(dtype_backend)
#     666
# --> 667     return impl.read(
#     668         path,
#     669         columns=columns,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parquet.py in read(self, path, columns, filters, use_nullable_dtypes, dtype_backend, storage_options, filesystem, **kwargs)
# ...

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

odsc_2024_nvidia_hackathon_path = kagglehub.competition_download('odsc-2024-nvidia-hackathon')

print('Data source import complete.')

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# IMPORTANT: SOME KAGGLE DATA SOURCES ARE PRIVATE
# RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES.
import kagglehub
kagglehub.login()

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.

odsc_2024_nvidia_hackathon_path = kagglehub.competition_download('odsc-2024-nvidia-hackathon')

print('Data source import complete.')

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Checking the shape cross-check
df.shape

# %%
df_obj = df.select_dtypes(include='object')

# %%
df_obj.head()

# %%
df_obj.nunique()

# %%
df.isna().mean().sort_values(ascending = False) * 100

# %%
missing_values = df.isna().sum()
missing_values = missing_values[missing_values > 0]
print(missing_values/len(df) * 100)

# %%
df.shape

# %%
df = df.dropna()
# Dropping Null Values

# %%
df.shape

# %%
df['y'].head()

# %%
! pip install category_encoders

# %%
# Label Encoding
import pandas as pd
from category_encoders import TargetEncoder

# Initialize the TargetEncoder
encoder = TargetEncoder(cols=['trickortreat', 'kingofhalloween'])

# Fit and transform the data
df_encoded = encoder.fit_transform(df[['trickortreat', 'kingofhalloween']], df['y'])

# Combine encoded columns with original target for a complete view
df_encoded['y'] = df['y']
# Display the transformed DataFrame
print(df_encoded.head())

# %%
df['trickortreat'] = df_encoded['trickortreat']
# df['trickortreat']
df['kingofhalloween'] = df_encoded['kingofhalloween']
df_encoded['kingofhalloween']

# %%
#  Cross Checking
# -1 might be null values

# %%
# I want to
correlation = df.corr()
target_correlation = correlation['y']
print(target_correlation)

# %%
pd.set_option('display.max_rows', 400)

# %%
# Find columns which have either really high +ve or -ve corr
target_correlation = correlation['y']


threshold = 0.1  # Adjust this value as needed

# Find columns with high positive or high negative correlation
high_correlation = target_correlation[(target_correlation > threshold) | (target_correlation < -threshold)]

# Remove the target variable itself from the results
high_correlation = high_correlation[high_correlation.index != 'target']

# Display the results
print(high_correlation)
high_correlation

# %%
#  Checking the correlation for the selected features
selected_features = ['noon','costumes','mystical','paranormal','quirky','cobwebs','kiddies','ma']

# %% [markdown]
# ### Key Finding
# Categorical values** trickortreat **and **kingofhalloween **
# 1) Essentially if we split on the basis of _ then the resultant values which we get can help us to drastically reduce the number of unique

# %%
# Pair plot with the columns which have the same correlation
import seaborn as sns
import matplotlib.pyplot as plt
data_sample  = df.sample(1000)
# the _ in between that meant 2 different columns which were when segrated give less unique values

selected_columns = ['noon', 'costumes', 'mystical', 'paranormal','y']

# Create a pair plot
sns.pairplot(data_sample[selected_columns], hue='y', diag_kind='kde')
plt.title('Pair Plot of Selected Features')
plt.show()

# %%
#  only king_ofhallowen ,trickortreat has high corr but that has been done via target encoding so its artifical
# Assuming you already have the correlation matrix
target_correlation = correlation['y']  # Replace 'y' with the actual name of your target variable

# Set the threshold
threshold = 0.1  # Adjust this value as needed

# Find columns with low correlation (less than 0.1)
low_correlation = target_correlation[(target_correlation < threshold) & (target_correlation > -threshold)]

# Remove the target variable itself from the results
low_correlation = low_correlation[low_correlation.index != 'y']  # Replace 'y' with your target variable name

# Get the list of columns with low correlation
low_correlation_list = low_correlation.index.tolist()

# Display the results
print(low_correlation.sort_values())
